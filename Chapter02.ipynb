# %% [markdown]
# # Ex. 2.1
#
# First we need to assume that the norm here is Euclidean norm $||\cdot||_2$, we also believe this is the case for any norm appearing in this book. The statement in this problem is true under Euclidean norm, but not necessarily true for other norms. Let's consider two vectors in $v_1, v_2 \in \mathbb{R}^2 $, where $ v_1 = [4,4]^T, v_2 = [6,1]^T $. We can see that:
# \begin{align*}
#   ||v_1||_1 >& \,||v_2||_1 \\
#   ||v_1||_2 <& \,||v_2||_2 .
# \end{align*}
#
# This indicates that for a given point, the nearest neighbor is not invariant with different choices of norms.
#
# Let's come back to prove the statment in this question:
# $$\mathrm{argmin}_k\left(\left\Vert t_k - \hat{y}\right\Vert_2\right) = \mathrm{argmax}_k\left(\hat{y}_k\right)$$
# **Proof**
# \begin{align*}
#   \mathrm{argmin}_k\left(\left\Vert t_k - \hat{y}\right\Vert_2\right)
#   =&\mathrm{argmin}_k\left(\left\Vert t_k - \hat{y}\right\Vert_2^2\right)\\
#   =&\mathrm{argmin}_k\sum_{i=1}^K\left( t_{k\,i} - \hat{y}_i\right)^2 \\
#   =&\mathrm{argmin}_k\sum_{i=1}^K\left(t_{k\,i}^2 + \hat{y}_i^2 - 2t_{k\,i}\hat{y}_i\right)\\
#   =&\mathrm{argmin}_k\left(1+\left\Vert\hat{y}\right\Vert_2^2-2\sum_{i=1}^Kt_{k\,i}\hat{y}_i\right)\\
#   =&\mathrm{argmin}_k\left(1+\left\Vert\hat{y}\right\Vert_2^2-2\hat{y}_k\right) \\
#   =&\mathrm{argmin}_k\left(-2\hat{y}_k\right) \\
#   =&\mathrm{argmax}_k\left(\hat{y}_k\right)
# \end{align*}∎

# %% [markdown]
# # Ex. 2.2
#
# The Bayes decision boundary is atainable because we know how the two classes (Blue and Organge) are generated. Let's first review on how these two classes are generated. We define a Gaussian bivariate distribution for each of the two classes, with the covariance matrix being the same $2\times2$ identity matrix $\mathbf{I}$, and mean vectors different. For the Blue class, the mean vector is $[1,0]^T$, and for the Organge $[0,1]^T$. Namely $\mathbf{Z}_1 = N\left([1,0]^T, \mathbf{I}\right), \mathbf{Z}_2 = N\left([0,1]^T, \mathbf{I}\right)$. For each of the two classes, we sample 10 times from its corresponding bivariate Gaussian vector. We denote the two set of samples as: $\mathbf{p}=\{p_i\}_{i=1}^{10}$ for the Blue and $\mathbf{q}=\{q_i\}_{i=1}^{10}$ for the Orange. Next, for each of the two classes, we first uniformly pick an element form $\mathbf{p}$ (or $\mathbf{q}$) to be the mean vector, and use $\frac15\mathbf{I}$ as the covariance matrix to form another bivariate Gaussian vector to generate a single realization. Such process is repeated for 100 times for each class.
#
# Now let's first look for the Bayes decision boundary conditional on $\mathbf{p}$ and $\mathbf{q}$, $\Gamma(\mathbf{p}, \mathbf{q})\in \mathbb{R}^2$. For any $x\in\mathbb{R}^2$. The probability of $x$ being blue is:
# $$P(x\,\mathrm{being\,blue})= \sum_{i=1}^{10}\frac1{10}\phi(x,p_i), $$
# where $\phi(x,p_i)$ is the probability density function at $x$ of a bivariate Guassian with mean $p_i$ and covariance matrix $\frac15\mathbf{I}$. Then the Bayes decision boundary conditional on $\mathbf{p}$ and $\mathbf{q}$ should be those points where being blue and orange are equally likely:
# $$\Gamma(\mathbf{p}, \mathbf{q})
# =\{x\in\mathbb{R}^2\vert \sum_{i=1}^{10}\phi(x, p_i)=\sum_{i=1}^{10}\phi(x, q_i)\}$$
#
# The final Bayes decision boundary should only be conditinal on given paramters $\mathbf{Z}_1$ and $\mathbf{Z}_2$, which should be the expectation of $\Gamma(\mathbf{p}, \mathbf{q})$ over all possible $\mathbf{p}$ or $\mathbf{q}$:
# \begin{align*}
# \Gamma(\mathbf{Z}_1, \mathbf{Z}_2) =& \Gamma(\mathrm{E}[\mathbf{p}],\mathrm{E}[\mathbf{q}])\\
# =&\{x \in \mathbb{R}^2\,\vert\,\phi(x,[1,0]^T)=\phi(x,[0,1]^T)\}\\
# =&\{x \in \mathbb{R}^2\,\vert\, x_1 = x_2\}.
# \end{align*}

# %% [markdown]
# # Ex. 2.3
#
# This excercise is related to ordered statistics, where the simplest case minimum is encountered. The volume of a $p$ dimmensional ball is proportional to $r^p$, where $r$ is its radius. Let's denote the random variable of the distance of any sampled point in this $p$ dimmentional unit ball to the origin as $Z$. Then,
# \begin{align*}
# P(Z < x)=&x^p, \\
# P(Z > x)=&1-x^p, \\
# P(Z_{(1)} > x) =& P(\prod_{i=1}^N Z_i > x)=\left(1-x^p\right)^N,\\
# P(Z_{(1)} < x) =& 1 - \left(1-x^p\right)^N.
# \end{align*}
# The median is the $\frac12$ quantile of $Z_{(1)}$, solve for $1-\left(1-x^p\right)^N=\frac12$ gives us:
# $$x=\left(1-\frac12^{1/N}\right)^{1/p}$$

# %% [markdown]
# # Ex. 2.4
#
# $z_i$ is a linear combination of all the elements of any realization of $\mathbf{X}$, so it must be one dimensional normal. $\mathbf{X} \sim N(0, \mathbf{I})$, therefore we have:
# \begin{align*}
# \mathrm{E}[z_i]=& 0,\\
# \mathrm{Var}(z_i)=&\sum_{i=1}^p\left(a_i^2\cdot1\right)=1.
# \end{align*}
#
# The expected squared distance of $z_i$ is:
# $$\mathrm{E}[\mathrm{d}(z_i,0)^2]=\mathrm{E}[z_i^2]=1.$$
#
# The expected squared distance for $x_0$ is:
# $$\mathrm{E}[\mathrm{d}(x_0,0)^2]=\mathrm{E}[x_0^2]=p,$$
# since $x_0^2 \sim \chi^2(p).$

# %% [markdown]
# # Ex. 2.5
#
# ## (a)
# This decomposition of expected prediction error is a general law for any prediction, and should be memorized:
# \begin{align*}
# \mathrm{E}\left[\left(y_{0}-\hat{y}_{0}\right)^{2}\right] & =\mathrm{E}\left[\left(y_{0}-\mathrm{E}[\hat{y}_{0}]+\mathrm{E}[\hat{y}_{0}]-\hat{y}_{0}\right)^{2}\right]\\
#  & =\mathrm{E}\left[\left(y_{0}-\mathrm{E}[\hat{y}_{0}]\right)^{2}\right]+\mathrm{E}\left[\left(\mathrm{E}[\hat{y}_{0}]-\hat{y}_{0}\right)^{2}\right]+0\\
#  & =\mathrm{E}\left[\left(y_{0}-\mathrm{E}[y_{0}]+\mathrm{E}[y_{0}]-\mathrm{E}[\hat{y}_{0}]\right)^{2}\right]+\mathrm{Var}[\hat{y}_{0}]\\
#  & =\mathrm{E}\left[\left(y_{0}-\mathrm{E}[y_{0}]\right)^{2}\right]+\mathrm{E}\left[\left(\mathrm{E}[y_{0}]-\mathrm{E}[\hat{y}_{0}]\right)^{2}\right]+0+\mathrm{Var}[\hat{y}_{0}]\\
#  & =\mathrm{Var}[y_{0}]+\left(\mathrm{E}[y_{0}]-\mathrm{E}[\hat{y}_{0}]\right)^{2}+\mathrm{Var}[\hat{y}_{0}]\\
#  & =\mathrm{Var}[y_{0}]+\mathrm{Bias}\left(\hat{y}_{0}\right)^{2}+\mathrm{Var}[\hat{y}_{0}]
# \end{align*}
# Following the notion in (2.4), where $\mathbf{X}$ is an $N\times p$ matrix with each row an input vector of the training set, and $\mathbf{y}$ is a $N$-vector of the output of the training set. The least square estimate of $\beta$ is given by:
# $$\hat{\beta}=\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\mathbf{X}^T\mathbf{y}.$$
# Then we have:
# \begin{align*}
#     y_0 - \hat{y}_0 =& x_0^T\beta+\varepsilon_0-x_0^T\hat{\beta} \\
#     =& x_0^T\beta+\varepsilon_0
#     -x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\mathbf{X}^T\mathbf{y} \\
#     =& x_0^T\beta+\varepsilon_0 - x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}
#     \mathbf{X}^T\left(\mathbf{X}\beta+\varepsilon\right) \\
#     =& \varepsilon_0 - x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\mathbf{X}^T\varepsilon.
# \end{align*}
# Knowing that $\varepsilon_0$ and $\varepsilon$ are independent:
# \begin{align*}
#     \mathrm{EPE}(x_0)=&\mathrm{E}[(y_0 - \hat{y}_0)^2]\\
#     =&\mathrm{E}\left[\left(\varepsilon_0 - x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}
#     \mathbf{X}^T\varepsilon\right)^2\right] \\
#     =&\mathrm{E}\left[\varepsilon_0^2\right] + \mathrm{E}\left[
#     x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\mathbf{X}^T\varepsilon
#     \varepsilon^T\mathbf{X}\left(\mathbf{X}^T\mathbf{X}\right)^{-1}x_0\right]+0 \\
#     =&\mathrm{E}\left[\varepsilon_0^2\right] + \mathrm{E}\left[
#     x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\mathbf{X}^T\mathrm{E}\left[\varepsilon
#     \varepsilon^T\right]\mathbf{X}\left(\mathbf{X}^T\mathbf{X}\right)^{-1}x_0\right]+0 \\
#     =&\sigma^2+\sigma^2\mathrm{E}\left[
#     x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\mathbf{X}^T\cdot\mathbf{I}\cdot
#     \mathbf{X}\left(\mathbf{X}^T\mathbf{X}\right)^{-1}x_0\right] \\
#     =&\sigma^2+\sigma^2\mathrm{E}\left[x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}x_0\right].
# \end{align*}
# According to the decomposition of expected prediction error:
# \begin{align*}
# \mathrm{Var}[y_{0}] & =\sigma^{2}\\
# \mathrm{Bias}\left(\hat{y}_{0}\right)^{2} & =0\\
# \mathrm{Var}[\hat{y}_{0}] & =\sigma^{2}\mathrm{E}\left[x_{0}^{T}\left(\mathbf{X}^{T}\mathbf{X}\right)^{-1}x_{0}\right]
# \end{align*}
# In the fourth line of the above equations, I assumed the following:
# $$\mathrm{E}[\mathbf{XYZ}]=\mathrm{E}[\mathbf{X}\cdot\mathrm{E}[\mathbf{Y}]\cdot\mathbf{Z}],$$
# where $\mathbf{X}$,$\mathbf{Y}$ and $\mathbf{Z}$ are random matrices, and $\mathbf{Y}$ is independent of both $\mathbf{X}$ and $\mathbf{Z}$. Let's take a step back to first prove for the scalar case:
# $$\mathrm{E}[\mathbf{xyz}]=\mathrm{E}[\mathbf{x}\cdot\mathrm{E}[\mathbf{y}]\cdot\mathbf{z}].$$
#
# By law of total expectation (or tower rule):
# \begin{align*}
# \mathrm{E}[\mathbf{xyz}] & =\mathrm{E}[\mathrm{E}[\mathbf{xyz}|\mathbf{y}]]\\
#  & =\mathrm{E}[\mathrm{E}[\mathbf{y}|\mathbf{y}]\cdot\mathrm{E}[\mathbf{xz}|\mathbf{y}]]\\
#  & =\mathrm{E}[\mathbf{y}\cdot\mathrm{E}[\mathbf{xz}|\mathbf{y}]]\\
#  & =\mathrm{E}[\mathbf{y}\cdot\mathrm{E}[\mathbf{xz}]]\qquad\mbox{by independence of}\,\,\mathbf{y}\\
#  & =\mathrm{E}[\mathbf{y}]\cdot\mathrm{E}[\mathbf{xz}]\\
#  & =\mathrm{E}[\mathbf{x}\cdot\mathrm{E}[\mathbf{y}]\cdot\mathbf{z}]
# \end{align*}
#
# The matrix case is straight forward by definition of matrix mutiplication:
# \begin{align*}
# \mathrm{E}[\mathbf{XYZ}]_{i,j} & =\mathrm{E}\left[\sum_{k}\sum_{l}\mathbf{X}_{i,k}\mathbf{Y}_{k,l}\mathbf{Z}_{l,j}\right]\\
#  & =\sum_{k}\sum_{l}\mathrm{E}[\mathbf{X}_{i,k}\mathbf{Y}_{k,l}\mathbf{Z}_{l,j}]\\
#  & =\sum_{k}\sum_{l}\mathrm{E}\left[\mathbf{X}_{i,k}\mathrm{E}[\mathbf{Y}_{k,l}]\mathbf{Z}_{l,j}\right]\\
#  & =\sum_{k}\sum_{l}\mathrm{E}\left[\mathbf{X}_{i,k}\mathrm{E}[\mathbf{Y}]_{k,l}\mathbf{Z}_{l,j}\right]\\
#  & =\mathrm{E}\left[\sum_{k}\sum_{l}\mathbf{X}_{i,k}\mathrm{E}[\mathbf{Y}]_{k,l}\mathbf{Z}_{l,j}\right]\\
#  & =\mathrm{E}[\mathbf{X}\cdot\mathrm{E}[\mathbf{Y}]\cdot\mathbf{Z}]_{i,j}
# \end{align*}
#
# ## (b)
#
# Assuming $\mathrm{E}[\mathbf{X}]=0$, by law of large number we have
# $$\frac{\mathbf{X}^T\mathbf{X}}{N}\rightarrow \mathrm{Cov}(\mathbf{x})\,
# \mathrm{when}\, N\rightarrow\infty.$$
# Further more,
# $$\frac{\mathrm{Cov}(\mathbf{x})^{-1}\mathbf{X}^T\mathbf{X}}{N}\rightarrow \mathbf{I}\,
# \mathrm{when}\, N\rightarrow\infty.$$
# $x_0$ has the same distribution as any row of $\mathbf{X}$:
# $$\mathrm{E}[x_0x_0^T]=\mathrm{Cov}(x_0)=\mathrm{Cov}(\mathbf{x}).$$
# Knowing that $x_0$ and $\mathbf{X}$ are independent, and that both $\mathrm{Cov}(\mathbf{x})$ and $\mathbf{X}^T\mathbf{X}$ are symmetric and invertible (for the latter, almost surely):
# \begin{align*}
# \mathrm{E}\left[x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}x_0\right] =&
# \mathrm{E}\left[\mathrm{Tr}\left(x_0x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\right)\right]\\
# =&\mathrm{Tr}\left(\mathrm{E}\left[x_0x_0^T\right]\cdot
# \mathrm{E}\left[\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\right]\right)\\
# =&\mathrm{Tr}\left(\mathrm{Cov}(\mathbf{x})\cdot
# \mathrm{E}\left[\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\right]\right)\\
# =&\mathrm{Tr}\left(\mathrm{E}\left[\mathrm{Cov}(\mathbf{x})
# \cdot\left(\mathbf{X}^T\mathbf{X}\right)^{-1}\right]\right)\\
# =& \mathrm{Tr}\left(\mathrm{E}\left[\left(\mathrm{Cov}(\mathbf{x})^{-1}
# \cdot\mathbf{X}^T\mathbf{X}\right)^{-1}\right]\right).\\
# \end{align*}
#
# The matrix inverse operator is a continuous operator on the space of $p\times p$ invertible matrices, as a result, we have:
# $$\left(\mathrm{Cov}(\mathbf{x})^{-1}
# \cdot\mathbf{X}^T\mathbf{X}\right)^{-1}\sim \left(N\cdot\mathbf{I}\right)^{-1}\,
# \mathrm{when}\, N\rightarrow\infty.$$
# One may notice that the matrix inverse operator is continuous but not uniformly continuous, so the above limit behavior holds true almost surely, since the uninvertible $p\times p$ matrices consists a negligible subset of the set of all $p\times p$ matrices.
#
# Finally we have:
# \begin{align*}
# \mathrm{Var}[\hat{y}_{0}]=
# \sigma^2\mathrm{E}\left[x_0^T\left(\mathbf{X}^T\mathbf{X}\right)^{-1}x_0\right] \sim&
# \sigma^2\mathrm{Tr}\left(\mathrm{E}\left[\left(N\cdot\mathbf{I}\right)^{-1}\right]\right)\\
# =& \sigma^2N^{-1}\mathrm{Tr}(\mathbf{I})\\
# =& \sigma^2p/N.
# \end{align*}
# This completes the derivation of (2.28).

# %% [markdown]
# # Ex. 2.6
#
# This problem asks us to prove that the simple least square estimator of $\theta$, equals some form of weighted least square estimator of $\theta$ when some values of $x_i$ are repeated. Suppose we have $N_i$ repeatitions of $x_i$, with outputs $y_{ij}$ where $j=1,\dots,N_i$. For input $x_i$ natrually we would guess that the weight for this data entry to be $N_i$, and the output to be the everage of all $N_j$ numbers of $y_{ij}$, let's denote it as $\bar{y_i}$. Now if we are lucky, the following can be proved:
# $$\mathrm{argmin}_\theta\sum_{i=1}^N\sum_{j=1}^{N_i}(f_\theta(x_i)-y_{ij})^2
# =\mathrm{argmin}_\theta\sum_{i=1}^NN_i(f_\theta(x_i)-\bar{y_i})^2$$
# **Proof**
# \begin{align*}
# \mathrm{argmin}_\theta\sum_{i=1}^N\sum_{j=1}^{N_i}(f_\theta(x_i)-y_{ij})^2
# =&\mathrm{argmin}_\theta\sum_{i=1}^N\sum_{j=1}^{N_i}
# \left(f_\theta(x_i)^2-2y_{ij}f_\theta(x_i)+y_{ij}^2\right)\\
# =&\mathrm{argmin}_\theta\sum_{i=1}^NN_i\left(f_\theta(x_i)^2-2f_\theta(x_i)\bar{y_i}
# +\bar{y_i}^2-\bar{y_i}^2+\frac1{N_i}\sum_{j=1}^{N_i}y_{ij}^2\right)\\
# =&\mathrm{argmin}_\theta\left(\sum_{i=1}^NN_i\left(f_\theta(x_i)-\bar{y_i}\right)^2
# +\sum_{i=1}^N\left(\sum_{j=1}^{N_i}y_{ij}^2-N_i\bar{y_i}^2\right)\right)\\
# =&\mathrm{argmin}_\theta\sum_{i=1}^NN_i\left(f_\theta(x_i)-\bar{y_i}\right)^2.
# \end{align*}∎
#
# The last line is based on the fact that $\sum_{i=1}^N\left(\sum_{j=1}^{N_i}y_{ij}^2-N_i\bar{y_i}^2\right)$ is not a function of $\theta$.

# %% [markdown]
# # Ex. 2.7
#
# Without loss of generality, let's assume $\mathbb{R}^p\overset{f}{\rightarrow}\mathbb{R}$. Namely, let $\mathbf{x}$ be the p dimensional random vector with $\{x_i | i=1,\dots,N\}$ as its $N$ realizations.
# ## (a)
# In the case of linear regression, $f(\mathbf{x})=\mathbf{x}^T\beta$. $\mathcal{X}$ will a $N\times p$ dimensional matrix with its $i$th row being $x_i^T$. The least square esimator of $\beta$ is:
# $$\hat{\beta}=\left(\mathcal{X}^T\mathcal{X}\right)^{-1}\mathcal{X}^T\mathcal{Y}.$$
# Therefore:
# \begin{align*}
# \hat{f}(x_0)=&x_0^T\hat{\beta}\\
# =&x_0^T\left(\mathcal{X}^T\mathcal{X}\right)^{-1}\mathcal{X}^T\mathcal{Y}\\
# =&\sum_{i=1}^Nl_i(x_0;\mathcal{X})y_i,
# \end{align*}
# where $l_i(x_0;\mathcal{X})$ is the $i$th element of the row vector $x_0^T\left(\mathcal{X}^T\mathcal{X}\right)^{-1}\mathcal{X}^T$, and $y_i$ is the $i$th element of the column vector of $\mathcal{Y}$.
#
# In the case of $k$-nearest-neighbor, $l_i(x_0;\mathcal{X})$ is either $1/k$, if the $x_i$ is in the set of $k$-nearest-neighbor of $x_0$, or $0$, if otherwise.
#
# In both cases $l_i(x_0;\mathcal{X})$ doesn't depend on $y_i$.
# ## (b)
# This is my first serious study in statistics and was confused about the notation at first. With help from a friend I learned that $\mathbf{E}_{X,Y|Z}[\cdot]$ means the same thing as $\mathbf{E}[\cdot|Z]$ in probability. It seems that statisticians love to keep themselves reminded about what the random variables are, and I can imagine that for regression there can be a lot of them. Weirdly, (but with all due respet) the unconditinal epxectation $\mathbf{E}[\cdot]$ in probability becomes $\mathbf{E}_{X,Y}[\cdot]$. Since we are learning statistics here, let's follow the notation.
# \begin{align*}
# \mathbf{E}_{\mathcal{Y|X}}\left(f(x_0)-\hat{f}(x_0)\right)^2=&
# \mathbf{E}_{\mathcal{Y|X}}\left(f(x_0) - \mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)
# +\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0) -\hat{f}(x_0)\right)^2\\
# =&\mathbf{E}_{\mathcal{Y|X}}\left(f(x_0)
# -\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)\right)^2
# +\mathbf{E}_{\mathcal{Y|X}}\left(\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)-\hat{f}(x_0)\right)^2\\
# &+2\mathbf{E}_{\mathcal{Y|X}}\left[\left(f(x_0)-\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)\right)
# \left(\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)-\hat{f}(x_0)\right)\right]
# \end{align*}
# In the last line, the first term is just $\left(f(x_0)-\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)\right)^2$, because it is not random given $\mathcal{X}$. The difference between the expection of an estimator and the true value is the bias of the estimator, so the first term is the square of the bias of $\hat{f}(x_0)$. The second term is the variance of $\hat{f}(x_0)$ by definition. Let's take a look at the third term. Since $f(x_{0})-\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_{0})$ is non-random, we have:
# \begin{align*}
# \mathbf{E}_{\mathcal{Y}|\mathcal{X}}\left[\left(f(x_{0})-\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})\right)\left(\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})-\hat{f}(x_{0})\right)\right] & =\left(f(x_{0})-\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})\right)\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\left[\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})-\hat{f}(x_{0})\right]\\
#  & =\left(f(x_{0})-\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})\right)\left(\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})-\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})\right)\\
#  & =\left(f(x_{0})-\mathbf{E}_{\mathcal{Y}|\mathcal{X}}\hat{f}(x_{0})\right)\cdot0=0
# \end{align*}
#
# Finally, we have:
# \begin{align*}
# \mathbf{E}_{\mathcal{Y|X}}\left(f(x_0)-\hat{f}(x_0)\right)^2
# =&\mathrm{Bias}(\hat{f}(x_{0})|\mathcal{X})^2+\mathrm{Var}(\hat{f}(x_{0})|\mathcal{X})\\
# =&\left(f(x_0)-\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)\right)^2
# + \mathbf{E}_{\mathcal{Y|X}}\left(\mathbf{E}_{\mathcal{Y|X}}\hat{f}(x_0)-\hat{f}(x_0)\right)^2
# \end{align*}
#
# ## (c)
# The derivation is the same for unconditional expected prediction error and the result is:
# \begin{align*}
# \mathbf{E}_{\mathcal{X},\mathcal{Y}}\left(f(x_{0})-\hat{f}(x_{0})\right)^{2} & =\mathrm{Bias}(\hat{f}(x_{0}))^{2}+\mathrm{Var}(\hat{f}(x_{0}))\\
#  & =\left(\mathbf{E}_{\mathcal{X},\mathcal{Y}}\hat{f}(x_{0})-f(x_{0})\right)^{2}+\mathbf{E}_{\mathcal{X},\mathcal{Y}}\left(\hat{f}(x_{0})-\mathbf{E}_{\mathcal{X},\mathcal{Y}}\left[\hat{f}(x_{0})\right]\right)^{2}
# \end{align*}
#
# ## (d)
# I don't quite understand what this problem is asking for. I'm writing down the results for linear regression when the true model is indeed a linear model.
# For the linear regression, the bias is zero regardless of conditioning. For the variance conditional on $\mathcal{X}$, we have:
# \begin{align*}
# \mathrm{Var}[\hat{f}(x_{0})|\mathcal{X}] & =\mathrm{E}\left[x_{0}^{T}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}\mathcal{X}^{T}\varepsilon\varepsilon^{T}\mathcal{X}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}x_{0}|\mathcal{X}\right]\\
#  & =x_{0}^{T}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}\mathcal{X}^{T}\mathrm{E}\left[\varepsilon\varepsilon^{T}|\mathcal{X}\right]\mathcal{X}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}x_{0}\\
#  & =x_{0}^{T}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}\mathcal{X}^{T}\sigma^{2}\mathbf{I}\mathcal{X}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}x_{0}\\
#  & =\sigma^{2}x_{0}^{T}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}\mathcal{X}^{T}\mathcal{X}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}x_{0}\\
#  & =\sigma^{2}x_{0}^{T}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}x_{0}
# \end{align*}
# For the unconditionl variance, following Ex. 2.5 (a):
# $$\mathrm{Var}[\hat{f}(x_{0})] =\sigma^{2}\mathrm{E}\left[x_{0}^{T}\left(\mathcal{X}^{T}\mathcal{X}\right)^{-1}x_{0}\right]$$

# %% [markdown]
# # Ex. 2.8
# The data files are download from the book website: www-stat.stanford.edu/ElemStatLearn, and stored at 'data/Chapter02'. Let's first load the data as pandas data frames.

# %%
import pandas as pd
import numpy as np
from os import getcwd
fname_train = getcwd()+'/data/Chapter02/zip.train'
fname_train2 = getcwd()+'/data/Chapter02/train.2'
fname_train3 = getcwd()+'/data/Chapter02/train.3'
fname_test = getcwd()+'/data/Chapter02/zip.test'
colnames = ['Digit']+['Grayvalue'+str(i) for i in range(0,256)]

train_dat=pd.read_table(fname_train,sep=' ',header=None,names=colnames,index_col=False)
train2_dat=pd.read_table(fname_train2,sep=',',header=None,names=colnames[1:],index_col=False)
train3_dat=pd.read_table(fname_train3,sep=',',header=None,names=colnames[1:],index_col=False)
test_dat=pd.read_table(fname_test,sep=' ',header=None,names=colnames,index_col=False)

num_train = train_dat.shape[0]
num_train2 = train2_dat.shape[0]
num_train3 = train3_dat.shape[0]
num_test = test_dat.shape[0]
# add exogenenous variable to fit the intercept
train_dat.insert(1,'intercept',pd.Series(np.ones(num_train),index=train_dat.index))
train2_dat.insert(0,'intercept',pd.Series(np.ones(num_train2),index=train2_dat.index))
train3_dat.insert(0,'intercept',pd.Series(np.ones(num_train3),index=train3_dat.index))
test_dat.insert(1,'intercept',pd.Series(np.ones(num_test),index=test_dat.index))

# %% [markdown]
# Let's firt try the ordinary linear least square with no intercept. In this case, a picture with gray scale value of 0 everywhere means 0.

# %%
from statsmodels.api import OLS

result_ols = OLS(endog=train_dat['Digit'], exog=train_dat[colnames[1:]]).fit()
result_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Digit   R-squared:                       0.872
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     187.6
# Date:                Sat, 26 Mar 2016   Prob (F-statistic):               0.00
# Time:                        17:22:13   Log-Likelihood:                -14463.
# No. Observations:                7291   AIC:                         2.944e+04
# Df Residuals:                    7035   BIC:                         3.120e+04
# Df Model:                         256
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Grayvalue0      -2.2494      0.632     -3.560      0.000        -3.488    -1.011
# Grayvalue1       0.1097      0.319      0.344      0.731        -0.516     0.735
# Grayvalue2      -0.1743      0.214     -0.813      0.416        -0.594     0.246
# Grayvalue3      -0.0129      0.147     -0.087      0.930        -0.302     0.276
# Grayvalue4      -0.2128      0.115     -1.848      0.065        -0.438     0.013
# Grayvalue5       0.0764      0.094      0.814      0.416        -0.108     0.260
# Grayvalue6      -0.1731      0.076     -2.280      0.023        -0.322    -0.024
# Grayvalue7      -0.5274      0.065     -8.062      0.000        -0.656    -0.399
# Grayvalue8       0.1279      0.063      2.038      0.042         0.005     0.251
# Grayvalue9       0.5461      0.069      7.860      0.000         0.410     0.682
# Grayvalue10      0.3896      0.077      5.042      0.000         0.238     0.541
# Grayvalue11      0.0134      0.089      0.151      0.880        -0.160     0.187
# Grayvalue12      0.1941      0.109      1.783      0.075        -0.019     0.408
# Grayvalue13      0.4146      0.149      2.779      0.005         0.122     0.707
# Grayvalue14      0.0300      0.222      0.135      0.893        -0.405     0.465
# Grayvalue15      0.7707      0.429      1.797      0.072        -0.070     1.611
# Grayvalue16     -0.4275      0.397     -1.076      0.282        -1.206     0.351
# Grayvalue17     -0.5740      0.227     -2.532      0.011        -1.018    -0.130
# Grayvalue18     -0.2431      0.147     -1.657      0.098        -0.531     0.044
# Grayvalue19     -0.2627      0.109     -2.415      0.016        -0.476    -0.049
# Grayvalue20     -0.1723      0.091     -1.891      0.059        -0.351     0.006
# Grayvalue21     -0.0794      0.084     -0.940      0.347        -0.245     0.086
# Grayvalue22      0.0149      0.081      0.183      0.855        -0.144     0.174
# Grayvalue23     -0.0059      0.079     -0.075      0.940        -0.161     0.149
# Grayvalue24     -0.0326      0.077     -0.424      0.671        -0.183     0.118
# Grayvalue25      0.2445      0.073      3.368      0.001         0.102     0.387
# Grayvalue26      0.1705      0.072      2.363      0.018         0.029     0.312
# Grayvalue27      0.1748      0.081      2.148      0.032         0.015     0.334
# Grayvalue28      0.2745      0.101      2.707      0.007         0.076     0.473
# Grayvalue29     -0.0626      0.134     -0.467      0.641        -0.325     0.200
# Grayvalue30      0.5375      0.193      2.787      0.005         0.159     0.916
# Grayvalue31     -0.0257      0.304     -0.085      0.933        -0.621     0.570
# Grayvalue32     -0.2479      0.282     -0.881      0.379        -0.800     0.304
# Grayvalue33      0.2480      0.183      1.353      0.176        -0.111     0.607
# Grayvalue34     -0.2158      0.123     -1.751      0.080        -0.457     0.026
# Grayvalue35     -0.0818      0.094     -0.872      0.383        -0.266     0.102
# Grayvalue36     -0.2217      0.081     -2.738      0.006        -0.380    -0.063
# Grayvalue37      0.0281      0.078      0.359      0.720        -0.125     0.181
# Grayvalue38     -0.0670      0.078     -0.859      0.390        -0.220     0.086
# Grayvalue39     -0.2958      0.080     -3.687      0.000        -0.453    -0.139
# Grayvalue40     -0.0482      0.079     -0.607      0.544        -0.204     0.108
# Grayvalue41     -0.1029      0.074     -1.398      0.162        -0.247     0.041
# Grayvalue42      0.2116      0.073      2.888      0.004         0.068     0.355
# Grayvalue43      0.0216      0.081      0.269      0.788        -0.136     0.180
# Grayvalue44      0.1992      0.096      2.076      0.038         0.011     0.387
# Grayvalue45      0.3339      0.129      2.583      0.010         0.080     0.587
# Grayvalue46      0.4897      0.194      2.528      0.011         0.110     0.869
# Grayvalue47      0.3171      0.273      1.159      0.246        -0.219     0.853
# Grayvalue48     -0.1994      0.263     -0.759      0.448        -0.714     0.315
# Grayvalue49     -0.4470      0.179     -2.492      0.013        -0.799    -0.095
# Grayvalue50     -0.1232      0.117     -1.051      0.293        -0.353     0.107
# Grayvalue51     -0.0185      0.092     -0.201      0.841        -0.199     0.162
# Grayvalue52     -0.0180      0.083     -0.218      0.828        -0.180     0.144
# Grayvalue53      0.0667      0.079      0.845      0.398        -0.088     0.221
# Grayvalue54     -0.1240      0.078     -1.582      0.114        -0.278     0.030
# Grayvalue55     -0.1208      0.082     -1.475      0.140        -0.281     0.040
# Grayvalue56     -0.1225      0.078     -1.572      0.116        -0.275     0.030
# Grayvalue57      0.0517      0.073      0.709      0.478        -0.091     0.195
# Grayvalue58      0.0449      0.078      0.577      0.564        -0.107     0.197
# Grayvalue59      0.1422      0.084      1.684      0.092        -0.023     0.308
# Grayvalue60      0.0591      0.099      0.595      0.552        -0.135     0.254
# Grayvalue61      0.1036      0.131      0.793      0.428        -0.152     0.360
# Grayvalue62     -0.3286      0.193     -1.701      0.089        -0.707     0.050
# Grayvalue63      0.4290      0.313      1.370      0.171        -0.185     1.043
# Grayvalue64      0.0131      0.280      0.047      0.963        -0.535     0.561
# Grayvalue65     -0.0953      0.170     -0.560      0.575        -0.428     0.238
# Grayvalue66     -0.1197      0.120     -0.995      0.320        -0.356     0.116
# Grayvalue67     -0.1131      0.096     -1.181      0.237        -0.301     0.075
# Grayvalue68     -0.0116      0.084     -0.139      0.890        -0.176     0.152
# Grayvalue69     -0.0652      0.080     -0.810      0.418        -0.223     0.093
# Grayvalue70      0.0840      0.081      1.031      0.302        -0.076     0.244
# Grayvalue71     -0.2163      0.084     -2.581      0.010        -0.381    -0.052
# Grayvalue72     -0.1106      0.082     -1.356      0.175        -0.271     0.049
# Grayvalue73     -0.3054      0.078     -3.916      0.000        -0.458    -0.153
# Grayvalue74      0.0737      0.082      0.904      0.366        -0.086     0.234
# Grayvalue75      0.0386      0.091      0.426      0.670        -0.139     0.216
# Grayvalue76      0.1274      0.104      1.223      0.222        -0.077     0.332
# Grayvalue77      0.1177      0.134      0.879      0.380        -0.145     0.380
# Grayvalue78      0.5170      0.193      2.674      0.008         0.138     0.896
# Grayvalue79      0.3078      0.353      0.871      0.384        -0.385     1.000
# Grayvalue80     -0.2968      0.273     -1.089      0.276        -0.831     0.238
# Grayvalue81      0.0367      0.176      0.208      0.835        -0.309     0.382
# Grayvalue82     -0.0176      0.129     -0.136      0.891        -0.270     0.235
# Grayvalue83      0.1100      0.101      1.092      0.275        -0.088     0.307
# Grayvalue84      0.0272      0.087      0.313      0.754        -0.143     0.197
# Grayvalue85      0.2997      0.083      3.626      0.000         0.138     0.462
# Grayvalue86      0.1042      0.081      1.280      0.201        -0.055     0.264
# Grayvalue87      0.0889      0.085      1.041      0.298        -0.078     0.256
# Grayvalue88     -0.0806      0.086     -0.939      0.348        -0.249     0.088
# Grayvalue89      0.0855      0.082      1.047      0.295        -0.075     0.246
# Grayvalue90     -0.0933      0.085     -1.092      0.275        -0.261     0.074
# Grayvalue91     -0.0287      0.091     -0.314      0.754        -0.208     0.151
# Grayvalue92     -0.0635      0.105     -0.607      0.544        -0.269     0.142
# Grayvalue93      0.2546      0.136      1.867      0.062        -0.013     0.522
# Grayvalue94      0.0056      0.195      0.029      0.977        -0.377     0.388
# Grayvalue95      0.2729      0.350      0.781      0.435        -0.412     0.958
# Grayvalue96      0.9254      0.279      3.319      0.001         0.379     1.472
# Grayvalue97     -0.1446      0.187     -0.772      0.440        -0.512     0.222
# Grayvalue98      0.0892      0.134      0.664      0.507        -0.174     0.353
# Grayvalue99     -0.2280      0.103     -2.216      0.027        -0.430    -0.026
# Grayvalue100    -0.0802      0.087     -0.918      0.359        -0.251     0.091
# Grayvalue101     0.1810      0.083      2.184      0.029         0.019     0.343
# Grayvalue102     0.1115      0.082      1.360      0.174        -0.049     0.272
# Grayvalue103    -0.0087      0.089     -0.098      0.922        -0.183     0.165
# Grayvalue104     0.1080      0.089      1.212      0.226        -0.067     0.283
# Grayvalue105     0.1214      0.085      1.432      0.152        -0.045     0.288
# Grayvalue106     0.0468      0.086      0.547      0.584        -0.121     0.215
# Grayvalue107     0.0897      0.089      1.012      0.312        -0.084     0.263
# Grayvalue108     0.0446      0.101      0.443      0.658        -0.153     0.242
# Grayvalue109    -0.1939      0.136     -1.430      0.153        -0.460     0.072
# Grayvalue110     0.0473      0.192      0.247      0.805        -0.329     0.423
# Grayvalue111    -0.3257      0.303     -1.075      0.283        -0.920     0.268
# Grayvalue112    -0.6563      0.268     -2.453      0.014        -1.181    -0.132
# Grayvalue113    -0.0669      0.185     -0.361      0.718        -0.431     0.297
# Grayvalue114    -0.2042      0.133     -1.536      0.125        -0.465     0.056
# Grayvalue115     0.0122      0.105      0.117      0.907        -0.193     0.217
# Grayvalue116     0.0486      0.089      0.545      0.586        -0.126     0.224
# Grayvalue117     0.0924      0.083      1.118      0.263        -0.070     0.254
# Grayvalue118     0.0913      0.085      1.072      0.284        -0.076     0.258
# Grayvalue119    -0.1563      0.090     -1.744      0.081        -0.332     0.019
# Grayvalue120     0.0707      0.088      0.800      0.424        -0.102     0.244
# Grayvalue121     0.1753      0.082      2.147      0.032         0.015     0.335
# Grayvalue122    -0.0799      0.084     -0.955      0.340        -0.244     0.084
# Grayvalue123    -0.0008      0.087     -0.009      0.993        -0.171     0.170
# Grayvalue124     0.0276      0.098      0.283      0.777        -0.164     0.219
# Grayvalue125     0.0885      0.125      0.705      0.481        -0.157     0.334
# Grayvalue126    -0.3171      0.178     -1.779      0.075        -0.666     0.032
# Grayvalue127    -0.5342      0.265     -2.016      0.044        -1.054    -0.015
# Grayvalue128     0.0762      0.244      0.312      0.755        -0.402     0.555
# Grayvalue129     0.0732      0.171      0.428      0.669        -0.262     0.409
# Grayvalue130    -0.1299      0.130     -0.999      0.318        -0.385     0.125
# Grayvalue131     0.0287      0.108      0.265      0.791        -0.183     0.241
# Grayvalue132    -0.2795      0.097     -2.872      0.004        -0.470    -0.089
# Grayvalue133     0.2871      0.091      3.153      0.002         0.109     0.466
# Grayvalue134     0.0688      0.093      0.743      0.457        -0.113     0.250
# Grayvalue135     0.0236      0.091      0.261      0.794        -0.154     0.201
# Grayvalue136     0.0971      0.085      1.142      0.253        -0.070     0.264
# Grayvalue137     0.1029      0.081      1.274      0.203        -0.055     0.261
# Grayvalue138     0.0940      0.081      1.160      0.246        -0.065     0.253
# Grayvalue139    -0.1155      0.085     -1.353      0.176        -0.283     0.052
# Grayvalue140    -0.0976      0.097     -1.003      0.316        -0.288     0.093
# Grayvalue141    -0.1023      0.121     -0.844      0.398        -0.340     0.135
# Grayvalue142    -0.0364      0.164     -0.221      0.825        -0.359     0.286
# Grayvalue143     0.0331      0.235      0.141      0.888        -0.428     0.494
# Grayvalue144    -0.0690      0.211     -0.327      0.744        -0.483     0.345
# Grayvalue145     0.0605      0.161      0.376      0.707        -0.254     0.375
# Grayvalue146    -0.0843      0.127     -0.661      0.508        -0.334     0.166
# Grayvalue147    -0.1471      0.111     -1.326      0.185        -0.365     0.070
# Grayvalue148     0.0303      0.104      0.291      0.771        -0.174     0.235
# Grayvalue149    -0.0733      0.100     -0.731      0.465        -0.270     0.123
# Grayvalue150     0.1479      0.100      1.485      0.137        -0.047     0.343
# Grayvalue151    -0.1086      0.093     -1.169      0.242        -0.291     0.073
# Grayvalue152     0.0077      0.084      0.092      0.927        -0.156     0.171
# Grayvalue153     0.2170      0.081      2.692      0.007         0.059     0.375
# Grayvalue154     0.0644      0.083      0.779      0.436        -0.098     0.226
# Grayvalue155    -0.1224      0.087     -1.411      0.158        -0.292     0.048
# Grayvalue156     0.0423      0.098      0.430      0.668        -0.151     0.235
# Grayvalue157    -0.2160      0.120     -1.797      0.072        -0.452     0.020
# Grayvalue158     0.1661      0.159      1.042      0.298        -0.146     0.479
# Grayvalue159    -0.1123      0.200     -0.561      0.575        -0.505     0.280
# Grayvalue160     0.2019      0.185      1.089      0.276        -0.162     0.565
# Grayvalue161    -0.3081      0.145     -2.122      0.034        -0.593    -0.023
# Grayvalue162     0.3112      0.121      2.563      0.010         0.073     0.549
# Grayvalue163    -0.0316      0.109     -0.290      0.771        -0.245     0.182
# Grayvalue164     0.0019      0.107      0.018      0.986        -0.208     0.212
# Grayvalue165    -0.1281      0.106     -1.212      0.226        -0.335     0.079
# Grayvalue166     0.1336      0.102      1.311      0.190        -0.066     0.333
# Grayvalue167     0.1108      0.093      1.196      0.232        -0.071     0.293
# Grayvalue168     0.0907      0.087      1.041      0.298        -0.080     0.261
# Grayvalue169     0.3359      0.082      4.120      0.000         0.176     0.496
# Grayvalue170     0.0028      0.082      0.034      0.973        -0.158     0.164
# Grayvalue171    -0.2609      0.088     -2.966      0.003        -0.433    -0.088
# Grayvalue172    -0.1439      0.099     -1.455      0.146        -0.338     0.050
# Grayvalue173    -0.0575      0.118     -0.488      0.626        -0.289     0.174
# Grayvalue174     0.1266      0.151      0.837      0.403        -0.170     0.423
# Grayvalue175    -0.1201      0.187     -0.644      0.520        -0.486     0.246
# Grayvalue176     0.0086      0.184      0.047      0.963        -0.353     0.370
# Grayvalue177     0.1510      0.132      1.145      0.252        -0.107     0.409
# Grayvalue178     0.1030      0.108      0.957      0.339        -0.108     0.314
# Grayvalue179     0.0846      0.099      0.851      0.395        -0.110     0.280
# Grayvalue180     0.0456      0.100      0.456      0.648        -0.150     0.241
# Grayvalue181     0.2344      0.099      2.357      0.018         0.039     0.429
# Grayvalue182    -0.1988      0.097     -2.058      0.040        -0.388    -0.009
# Grayvalue183    -0.1962      0.094     -2.088      0.037        -0.380    -0.012
# Grayvalue184     0.3178      0.087      3.644      0.000         0.147     0.489
# Grayvalue185     0.0013      0.080      0.017      0.987        -0.155     0.158
# Grayvalue186    -0.1569      0.079     -1.980      0.048        -0.312    -0.002
# Grayvalue187    -0.1153      0.086     -1.335      0.182        -0.285     0.054
# Grayvalue188    -0.0766      0.099     -0.775      0.438        -0.270     0.117
# Grayvalue189    -0.0692      0.114     -0.607      0.544        -0.293     0.154
# Grayvalue190    -0.2010      0.140     -1.438      0.151        -0.475     0.073
# Grayvalue191    -0.0998      0.177     -0.564      0.573        -0.447     0.247
# Grayvalue192    -0.0073      0.213     -0.034      0.973        -0.425     0.410
# Grayvalue193     0.1374      0.130      1.060      0.289        -0.117     0.391
# Grayvalue194    -0.0222      0.102     -0.217      0.828        -0.223     0.179
# Grayvalue195     0.1497      0.093      1.604      0.109        -0.033     0.333
# Grayvalue196    -0.0548      0.091     -0.601      0.548        -0.234     0.124
# Grayvalue197     0.0773      0.088      0.876      0.381        -0.096     0.250
# Grayvalue198     0.1308      0.089      1.466      0.143        -0.044     0.306
# Grayvalue199    -0.0429      0.091     -0.470      0.638        -0.222     0.136
# Grayvalue200     0.0234      0.085      0.275      0.783        -0.144     0.190
# Grayvalue201    -0.0206      0.078     -0.263      0.792        -0.174     0.133
# Grayvalue202     0.0262      0.080      0.329      0.742        -0.130     0.182
# Grayvalue203    -0.3165      0.086     -3.683      0.000        -0.485    -0.148
# Grayvalue204    -0.1489      0.098     -1.517      0.129        -0.341     0.043
# Grayvalue205    -0.1247      0.113     -1.101      0.271        -0.347     0.097
# Grayvalue206    -0.1205      0.137     -0.882      0.378        -0.388     0.147
# Grayvalue207     0.0563      0.187      0.301      0.763        -0.311     0.423
# Grayvalue208    -0.0971      0.246     -0.394      0.693        -0.580     0.386
# Grayvalue209     0.3705      0.153      2.418      0.016         0.070     0.671
# Grayvalue210    -0.0081      0.108     -0.075      0.940        -0.220     0.204
# Grayvalue211     0.2067      0.094      2.199      0.028         0.022     0.391
# Grayvalue212     0.0431      0.089      0.484      0.628        -0.132     0.218
# Grayvalue213     0.3290      0.084      3.900      0.000         0.164     0.494
# Grayvalue214     0.1475      0.083      1.774      0.076        -0.016     0.311
# Grayvalue215    -0.0324      0.088     -0.367      0.714        -0.205     0.140
# Grayvalue216    -0.3186      0.086     -3.714      0.000        -0.487    -0.150
# Grayvalue217    -0.0363      0.081     -0.447      0.655        -0.195     0.123
# Grayvalue218     0.1705      0.086      1.991      0.046         0.003     0.338
# Grayvalue219    -0.1047      0.092     -1.135      0.257        -0.285     0.076
# Grayvalue220    -0.3114      0.102     -3.038      0.002        -0.512    -0.110
# Grayvalue221    -0.1312      0.124     -1.062      0.288        -0.373     0.111
# Grayvalue222    -0.3549      0.161     -2.209      0.027        -0.670    -0.040
# Grayvalue223    -0.1197      0.212     -0.564      0.573        -0.536     0.297
# Grayvalue224     0.0324      0.336      0.097      0.923        -0.625     0.690
# Grayvalue225     0.0035      0.203      0.017      0.986        -0.395     0.402
# Grayvalue226     0.1110      0.141      0.788      0.431        -0.165     0.387
# Grayvalue227     0.3422      0.109      3.144      0.002         0.129     0.556
# Grayvalue228    -0.0320      0.097     -0.330      0.741        -0.222     0.158
# Grayvalue229     0.1395      0.089      1.565      0.118        -0.035     0.314
# Grayvalue230    -0.1542      0.083     -1.850      0.064        -0.318     0.009
# Grayvalue231     0.0896      0.084      1.068      0.286        -0.075     0.254
# Grayvalue232     0.0224      0.086      0.260      0.795        -0.147     0.191
# Grayvalue233    -0.2213      0.085     -2.612      0.009        -0.387    -0.055
# Grayvalue234    -0.0135      0.090     -0.150      0.881        -0.189     0.163
# Grayvalue235    -0.1350      0.102     -1.326      0.185        -0.335     0.065
# Grayvalue236    -0.3331      0.120     -2.767      0.006        -0.569    -0.097
# Grayvalue237    -0.1089      0.157     -0.694      0.488        -0.417     0.199
# Grayvalue238    -0.0638      0.213     -0.299      0.765        -0.482     0.354
# Grayvalue239    -0.5120      0.266     -1.924      0.054        -1.034     0.010
# Grayvalue240    -0.6069      0.671     -0.905      0.366        -1.922     0.708
# Grayvalue241     0.2916      0.363      0.804      0.422        -0.420     1.003
# Grayvalue242     0.1892      0.254      0.746      0.456        -0.308     0.686
# Grayvalue243    -0.0107      0.177     -0.061      0.952        -0.357     0.336
# Grayvalue244     0.0593      0.137      0.432      0.666        -0.210     0.328
# Grayvalue245     0.2065      0.104      1.977      0.048         0.002     0.411
# Grayvalue246     0.3751      0.080      4.706      0.000         0.219     0.531
# Grayvalue247     0.0451      0.065      0.695      0.487        -0.082     0.172
# Grayvalue248    -0.3276      0.066     -4.978      0.000        -0.457    -0.199
# Grayvalue249    -0.0554      0.077     -0.722      0.470        -0.206     0.095
# Grayvalue250    -0.2582      0.104     -2.493      0.013        -0.461    -0.055
# Grayvalue251     0.4788      0.138      3.479      0.001         0.209     0.749
# Grayvalue252    -0.4359      0.171     -2.556      0.011        -0.770    -0.102
# Grayvalue253    -0.4985      0.220     -2.268      0.023        -0.929    -0.068
# Grayvalue254    -0.4245      0.292     -1.452      0.147        -0.998     0.149
# Grayvalue255    -0.3911      0.477     -0.820      0.412        -1.326     0.544
# ==============================================================================
# Omnibus:                       98.271   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.263
# Skew:                           0.242   Prob(JB):                     1.14e-24
# Kurtosis:                       3.358   Cond. No.                         379.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Next we examine the OLS model fitting results by testing on both the training set and test set. We round the prediction to the nearest integer, with a floor of 0 and a cap of 9. The we count the percetage of predictions that is correct. We achieve roughly 20~30% success rate for digit recognition by using OLS with no intercept.

# %%
# prediction using the entire test set
pred_test = result_ols.predict(test_dat[colnames[1:]])
pred_test=np.round(pred_test)
pred_test[pred_test<0]=0
pred_test[pred_test>9]=9
print("Correct rate on test set:")
print(sum(pred_test==test_dat['Digit'])/num_test)
# prediction using the entire training set
pred_train = result_ols.predict(train_dat[colnames[1:]])
pred_train=np.round(pred_train)
pred_train[pred_train<0]=0
pred_train[pred_train>9]=9
print("Correct rate on entire train set:")
print(sum(pred_train==train_dat['Digit'])/num_train)
# prediction using the training set with the digit being 2
pred_train2 = result_ols.predict(train2_dat[colnames[1:]])
pred_train2=np.round(pred_train2)
pred_train2[pred_train2<0]=0
pred_train2[pred_train2>9]=9
print("Correct rate on training set with the digit being 2:")
print(sum(pred_train2==2)/num_train2)
# prediction using the training set with the digit being 3
pred_train3 = result_ols.predict(train3_dat[colnames[1:]])
pred_train3=np.round(pred_train2)
pred_train3[pred_train3<0]=0
pred_train3[pred_train3>9]=9
print("Correct rate on training set with the digit being 3:")
print(sum(pred_train3==3)/num_train3)
# Out:
# Correct rate on test set:
# 0.254608868959
# Correct rate on entire train set:
# 0.269784666027
# Correct rate on training set with the digit being 2:
# 0.243502051984
# Correct rate on training set with the digit being 3:
# 0.306990881459

# %% [markdown]
# Next we try the OLS with intercept. In this case zero grey scale value every where represents a digit specified by the intercept rounded up to the nearest integer.

# %%
from statsmodels.api import OLS

result_ols_intercept = OLS(endog=train_dat['Digit'], exog=train_dat[['intercept']+colnames[1:]]).fit()
result_ols_intercept.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Digit   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     52.25
# Date:                Sat, 26 Mar 2016   Prob (F-statistic):               0.00
# Time:                        17:22:14   Log-Likelihood:                -14463.
# No. Observations:                7291   AIC:                         2.944e+04
# Df Residuals:                    7034   BIC:                         3.121e+04
# Df Model:                         256
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# intercept        0.6094      1.000      0.610      0.542        -1.350     2.569
# Grayvalue0      -2.1020      0.677     -3.107      0.002        -3.428    -0.776
# Grayvalue1       0.0912      0.320      0.285      0.776        -0.537     0.719
# Grayvalue2      -0.1640      0.215     -0.763      0.446        -0.585     0.257
# Grayvalue3      -0.0123      0.147     -0.084      0.933        -0.301     0.277
# Grayvalue4      -0.2103      0.115     -1.825      0.068        -0.436     0.016
# Grayvalue5       0.0771      0.094      0.822      0.411        -0.107     0.261
# Grayvalue6      -0.1719      0.076     -2.263      0.024        -0.321    -0.023
# Grayvalue7      -0.5271      0.065     -8.056      0.000        -0.655    -0.399
# Grayvalue8       0.1285      0.063      2.047      0.041         0.005     0.252
# Grayvalue9       0.5471      0.070      7.872      0.000         0.411     0.683
# Grayvalue10      0.3904      0.077      5.051      0.000         0.239     0.542
# Grayvalue11      0.0151      0.089      0.170      0.865        -0.159     0.189
# Grayvalue12      0.1951      0.109      1.791      0.073        -0.018     0.409
# Grayvalue13      0.4200      0.149      2.810      0.005         0.127     0.713
# Grayvalue14      0.0255      0.222      0.115      0.909        -0.410     0.461
# Grayvalue15      0.8472      0.447      1.896      0.058        -0.029     1.723
# Grayvalue16     -0.4202      0.398     -1.057      0.291        -1.200     0.359
# Grayvalue17     -0.5871      0.228     -2.578      0.010        -1.034    -0.141
# Grayvalue18     -0.2423      0.147     -1.651      0.099        -0.530     0.045
# Grayvalue19     -0.2652      0.109     -2.436      0.015        -0.479    -0.052
# Grayvalue20     -0.1715      0.091     -1.883      0.060        -0.350     0.007
# Grayvalue21     -0.0798      0.084     -0.946      0.344        -0.245     0.086
# Grayvalue22      0.0150      0.081      0.185      0.854        -0.144     0.174
# Grayvalue23     -0.0061      0.079     -0.077      0.939        -0.161     0.149
# Grayvalue24     -0.0328      0.077     -0.428      0.669        -0.183     0.118
# Grayvalue25      0.2435      0.073      3.353      0.001         0.101     0.386
# Grayvalue26      0.1702      0.072      2.358      0.018         0.029     0.312
# Grayvalue27      0.1734      0.081      2.129      0.033         0.014     0.333
# Grayvalue28      0.2722      0.101      2.683      0.007         0.073     0.471
# Grayvalue29     -0.0653      0.134     -0.487      0.626        -0.328     0.198
# Grayvalue30      0.5346      0.193      2.771      0.006         0.156     0.913
# Grayvalue31     -0.0451      0.305     -0.148      0.883        -0.644     0.554
# Grayvalue32     -0.2229      0.285     -0.783      0.434        -0.781     0.335
# Grayvalue33      0.2403      0.184      1.308      0.191        -0.120     0.601
# Grayvalue34     -0.2114      0.123     -1.712      0.087        -0.454     0.031
# Grayvalue35     -0.0818      0.094     -0.873      0.383        -0.266     0.102
# Grayvalue36     -0.2209      0.081     -2.728      0.006        -0.380    -0.062
# Grayvalue37      0.0279      0.078      0.356      0.721        -0.125     0.181
# Grayvalue38     -0.0666      0.078     -0.854      0.393        -0.220     0.086
# Grayvalue39     -0.2948      0.080     -3.673      0.000        -0.452    -0.137
# Grayvalue40     -0.0490      0.079     -0.616      0.538        -0.205     0.107
# Grayvalue41     -0.1017      0.074     -1.382      0.167        -0.246     0.043
# Grayvalue42      0.2104      0.073      2.871      0.004         0.067     0.354
# Grayvalue43      0.0220      0.081      0.273      0.785        -0.136     0.180
# Grayvalue44      0.1993      0.096      2.077      0.038         0.011     0.387
# Grayvalue45      0.3347      0.129      2.589      0.010         0.081     0.588
# Grayvalue46      0.4882      0.194      2.520      0.012         0.108     0.868
# Grayvalue47      0.3242      0.274      1.185      0.236        -0.212     0.861
# Grayvalue48     -0.1864      0.263     -0.707      0.479        -0.703     0.330
# Grayvalue49     -0.4472      0.179     -2.493      0.013        -0.799    -0.096
# Grayvalue50     -0.1235      0.117     -1.053      0.292        -0.353     0.106
# Grayvalue51     -0.0178      0.092     -0.193      0.847        -0.198     0.162
# Grayvalue52     -0.0179      0.083     -0.216      0.829        -0.180     0.144
# Grayvalue53      0.0666      0.079      0.844      0.399        -0.088     0.221
# Grayvalue54     -0.1244      0.078     -1.587      0.113        -0.278     0.029
# Grayvalue55     -0.1205      0.082     -1.472      0.141        -0.281     0.040
# Grayvalue56     -0.1213      0.078     -1.556      0.120        -0.274     0.032
# Grayvalue57      0.0505      0.073      0.693      0.488        -0.092     0.194
# Grayvalue58      0.0450      0.078      0.578      0.563        -0.107     0.197
# Grayvalue59      0.1429      0.084      1.693      0.091        -0.023     0.308
# Grayvalue60      0.0576      0.099      0.580      0.562        -0.137     0.252
# Grayvalue61      0.1065      0.131      0.815      0.415        -0.150     0.363
# Grayvalue62     -0.3319      0.193     -1.717      0.086        -0.711     0.047
# Grayvalue63      0.4290      0.313      1.370      0.171        -0.185     1.043
# Grayvalue64      0.0205      0.280      0.073      0.942        -0.528     0.569
# Grayvalue65     -0.0992      0.170     -0.583      0.560        -0.433     0.234
# Grayvalue66     -0.1192      0.120     -0.990      0.322        -0.355     0.117
# Grayvalue67     -0.1138      0.096     -1.188      0.235        -0.301     0.074
# Grayvalue68     -0.0109      0.084     -0.131      0.896        -0.175     0.153
# Grayvalue69     -0.0646      0.080     -0.803      0.422        -0.222     0.093
# Grayvalue70      0.0848      0.081      1.041      0.298        -0.075     0.245
# Grayvalue71     -0.2176      0.084     -2.595      0.009        -0.382    -0.053
# Grayvalue72     -0.1103      0.082     -1.352      0.176        -0.270     0.050
# Grayvalue73     -0.3061      0.078     -3.924      0.000        -0.459    -0.153
# Grayvalue74      0.0737      0.082      0.903      0.367        -0.086     0.234
# Grayvalue75      0.0369      0.091      0.407      0.684        -0.141     0.215
# Grayvalue76      0.1276      0.104      1.224      0.221        -0.077     0.332
# Grayvalue77      0.1164      0.134      0.869      0.385        -0.146     0.379
# Grayvalue78      0.5133      0.193      2.653      0.008         0.134     0.893
# Grayvalue79      0.3172      0.354      0.897      0.370        -0.376     1.011
# Grayvalue80     -0.2865      0.273     -1.049      0.294        -0.822     0.249
# Grayvalue81      0.0344      0.176      0.195      0.845        -0.311     0.380
# Grayvalue82     -0.0155      0.129     -0.120      0.904        -0.268     0.237
# Grayvalue83      0.1111      0.101      1.103      0.270        -0.086     0.309
# Grayvalue84      0.0273      0.087      0.315      0.753        -0.143     0.198
# Grayvalue85      0.2997      0.083      3.626      0.000         0.138     0.462
# Grayvalue86      0.1043      0.081      1.281      0.200        -0.055     0.264
# Grayvalue87      0.0901      0.085      1.056      0.291        -0.077     0.257
# Grayvalue88     -0.0803      0.086     -0.936      0.349        -0.249     0.088
# Grayvalue89      0.0853      0.082      1.045      0.296        -0.075     0.245
# Grayvalue90     -0.0926      0.085     -1.084      0.278        -0.260     0.075
# Grayvalue91     -0.0285      0.091     -0.311      0.756        -0.208     0.151
# Grayvalue92     -0.0637      0.105     -0.608      0.543        -0.269     0.142
# Grayvalue93      0.2562      0.136      1.878      0.060        -0.011     0.524
# Grayvalue94      0.0017      0.195      0.009      0.993        -0.381     0.385
# Grayvalue95      0.2779      0.350      0.795      0.427        -0.408     0.963
# Grayvalue96      0.9276      0.279      3.326      0.001         0.381     1.474
# Grayvalue97     -0.1453      0.187     -0.776      0.438        -0.512     0.222
# Grayvalue98      0.0870      0.134      0.648      0.517        -0.176     0.350
# Grayvalue99     -0.2281      0.103     -2.218      0.027        -0.430    -0.026
# Grayvalue100    -0.0803      0.087     -0.920      0.358        -0.252     0.091
# Grayvalue101     0.1813      0.083      2.187      0.029         0.019     0.344
# Grayvalue102     0.1119      0.082      1.365      0.172        -0.049     0.273
# Grayvalue103    -0.0093      0.089     -0.105      0.916        -0.183     0.165
# Grayvalue104     0.1079      0.089      1.211      0.226        -0.067     0.283
# Grayvalue105     0.1220      0.085      1.439      0.150        -0.044     0.288
# Grayvalue106     0.0457      0.086      0.534      0.594        -0.122     0.214
# Grayvalue107     0.0908      0.089      1.024      0.306        -0.083     0.265
# Grayvalue108     0.0444      0.101      0.441      0.659        -0.153     0.242
# Grayvalue109    -0.1941      0.136     -1.431      0.152        -0.460     0.072
# Grayvalue110     0.0460      0.192      0.240      0.811        -0.330     0.422
# Grayvalue111    -0.3206      0.303     -1.057      0.290        -0.915     0.274
# Grayvalue112    -0.6509      0.268     -2.431      0.015        -1.176    -0.126
# Grayvalue113    -0.0679      0.185     -0.366      0.715        -0.431     0.296
# Grayvalue114    -0.2019      0.133     -1.517      0.129        -0.463     0.059
# Grayvalue115     0.0127      0.105      0.121      0.903        -0.192     0.218
# Grayvalue116     0.0490      0.089      0.549      0.583        -0.126     0.224
# Grayvalue117     0.0930      0.083      1.126      0.260        -0.069     0.255
# Grayvalue118     0.0905      0.085      1.062      0.288        -0.077     0.257
# Grayvalue119    -0.1551      0.090     -1.730      0.084        -0.331     0.021
# Grayvalue120     0.0697      0.088      0.790      0.430        -0.103     0.243
# Grayvalue121     0.1744      0.082      2.135      0.033         0.014     0.334
# Grayvalue122    -0.0785      0.084     -0.937      0.349        -0.243     0.086
# Grayvalue123    -0.0022      0.087     -0.025      0.980        -0.173     0.168
# Grayvalue124     0.0272      0.098      0.278      0.781        -0.164     0.218
# Grayvalue125     0.0891      0.125      0.710      0.478        -0.157     0.335
# Grayvalue126    -0.3181      0.178     -1.785      0.074        -0.668     0.031
# Grayvalue127    -0.5331      0.265     -2.012      0.044        -1.053    -0.014
# Grayvalue128     0.0770      0.244      0.316      0.752        -0.401     0.555
# Grayvalue129     0.0752      0.171      0.439      0.660        -0.260     0.411
# Grayvalue130    -0.1308      0.130     -1.006      0.315        -0.386     0.124
# Grayvalue131     0.0284      0.108      0.263      0.793        -0.184     0.240
# Grayvalue132    -0.2802      0.097     -2.879      0.004        -0.471    -0.089
# Grayvalue133     0.2864      0.091      3.144      0.002         0.108     0.465
# Grayvalue134     0.0696      0.093      0.751      0.452        -0.112     0.251
# Grayvalue135     0.0225      0.091      0.248      0.804        -0.155     0.200
# Grayvalue136     0.0983      0.085      1.155      0.248        -0.068     0.265
# Grayvalue137     0.1033      0.081      1.278      0.201        -0.055     0.262
# Grayvalue138     0.0940      0.081      1.160      0.246        -0.065     0.253
# Grayvalue139    -0.1152      0.085     -1.350      0.177        -0.283     0.052
# Grayvalue140    -0.0971      0.097     -0.998      0.318        -0.288     0.094
# Grayvalue141    -0.1028      0.121     -0.848      0.396        -0.340     0.135
# Grayvalue142    -0.0366      0.164     -0.223      0.824        -0.359     0.286
# Grayvalue143     0.0366      0.235      0.156      0.876        -0.424     0.498
# Grayvalue144    -0.0671      0.211     -0.317      0.751        -0.481     0.347
# Grayvalue145     0.0596      0.161      0.371      0.711        -0.255     0.374
# Grayvalue146    -0.0849      0.127     -0.666      0.506        -0.335     0.165
# Grayvalue147    -0.1453      0.111     -1.309      0.191        -0.363     0.072
# Grayvalue148     0.0306      0.104      0.293      0.769        -0.174     0.235
# Grayvalue149    -0.0726      0.100     -0.724      0.469        -0.269     0.124
# Grayvalue150     0.1470      0.100      1.476      0.140        -0.048     0.342
# Grayvalue151    -0.1083      0.093     -1.167      0.243        -0.290     0.074
# Grayvalue152     0.0068      0.084      0.081      0.935        -0.157     0.171
# Grayvalue153     0.2171      0.081      2.693      0.007         0.059     0.375
# Grayvalue154     0.0640      0.083      0.774      0.439        -0.098     0.226
# Grayvalue155    -0.1222      0.087     -1.409      0.159        -0.292     0.048
# Grayvalue156     0.0423      0.098      0.430      0.667        -0.151     0.235
# Grayvalue157    -0.2161      0.120     -1.798      0.072        -0.452     0.020
# Grayvalue158     0.1668      0.159      1.046      0.296        -0.146     0.479
# Grayvalue159    -0.1135      0.200     -0.567      0.571        -0.506     0.279
# Grayvalue160     0.2034      0.185      1.097      0.273        -0.160     0.567
# Grayvalue161    -0.3105      0.145     -2.137      0.033        -0.595    -0.026
# Grayvalue162     0.3125      0.121      2.572      0.010         0.074     0.551
# Grayvalue163    -0.0344      0.109     -0.316      0.752        -0.248     0.179
# Grayvalue164     0.0022      0.107      0.020      0.984        -0.208     0.212
# Grayvalue165    -0.1289      0.106     -1.218      0.223        -0.336     0.079
# Grayvalue166     0.1330      0.102      1.305      0.192        -0.067     0.333
# Grayvalue167     0.1114      0.093      1.202      0.229        -0.070     0.293
# Grayvalue168     0.0923      0.087      1.059      0.290        -0.079     0.263
# Grayvalue169     0.3357      0.082      4.117      0.000         0.176     0.496
# Grayvalue170     0.0037      0.082      0.045      0.964        -0.158     0.165
# Grayvalue171    -0.2609      0.088     -2.966      0.003        -0.433    -0.088
# Grayvalue172    -0.1429      0.099     -1.446      0.148        -0.337     0.051
# Grayvalue173    -0.0583      0.118     -0.494      0.621        -0.289     0.173
# Grayvalue174     0.1284      0.151      0.849      0.396        -0.168     0.425
# Grayvalue175    -0.1177      0.187     -0.631      0.528        -0.484     0.248
# Grayvalue176     0.0118      0.184      0.064      0.949        -0.350     0.373
# Grayvalue177     0.1497      0.132      1.136      0.256        -0.109     0.408
# Grayvalue178     0.1028      0.108      0.956      0.339        -0.108     0.314
# Grayvalue179     0.0853      0.099      0.857      0.391        -0.110     0.280
# Grayvalue180     0.0465      0.100      0.465      0.642        -0.149     0.242
# Grayvalue181     0.2334      0.099      2.346      0.019         0.038     0.428
# Grayvalue182    -0.1982      0.097     -2.051      0.040        -0.388    -0.009
# Grayvalue183    -0.1971      0.094     -2.097      0.036        -0.381    -0.013
# Grayvalue184     0.3174      0.087      3.639      0.000         0.146     0.488
# Grayvalue185     0.0023      0.080      0.029      0.977        -0.155     0.159
# Grayvalue186    -0.1568      0.079     -1.979      0.048        -0.312    -0.001
# Grayvalue187    -0.1154      0.086     -1.337      0.181        -0.285     0.054
# Grayvalue188    -0.0767      0.099     -0.775      0.438        -0.271     0.117
# Grayvalue189    -0.0682      0.114     -0.598      0.550        -0.292     0.155
# Grayvalue190    -0.2027      0.140     -1.450      0.147        -0.477     0.071
# Grayvalue191    -0.0964      0.177     -0.544      0.586        -0.444     0.251
# Grayvalue192    -0.0095      0.213     -0.045      0.964        -0.427     0.408
# Grayvalue193     0.1357      0.130      1.046      0.296        -0.119     0.390
# Grayvalue194    -0.0218      0.102     -0.213      0.831        -0.223     0.179
# Grayvalue195     0.1488      0.093      1.594      0.111        -0.034     0.332
# Grayvalue196    -0.0564      0.091     -0.618      0.537        -0.235     0.122
# Grayvalue197     0.0774      0.088      0.877      0.381        -0.096     0.250
# Grayvalue198     0.1310      0.089      1.468      0.142        -0.044     0.306
# Grayvalue199    -0.0429      0.091     -0.470      0.639        -0.222     0.136
# Grayvalue200     0.0238      0.085      0.280      0.780        -0.143     0.191
# Grayvalue201    -0.0222      0.078     -0.283      0.777        -0.176     0.131
# Grayvalue202     0.0263      0.080      0.331      0.741        -0.130     0.182
# Grayvalue203    -0.3169      0.086     -3.688      0.000        -0.485    -0.148
# Grayvalue204    -0.1490      0.098     -1.518      0.129        -0.341     0.043
# Grayvalue205    -0.1241      0.113     -1.096      0.273        -0.346     0.098
# Grayvalue206    -0.1206      0.137     -0.883      0.377        -0.388     0.147
# Grayvalue207     0.0605      0.187      0.323      0.747        -0.307     0.428
# Grayvalue208    -0.0780      0.248     -0.314      0.753        -0.565     0.409
# Grayvalue209     0.3700      0.153      2.415      0.016         0.070     0.670
# Grayvalue210    -0.0054      0.108     -0.050      0.960        -0.217     0.207
# Grayvalue211     0.2046      0.094      2.175      0.030         0.020     0.389
# Grayvalue212     0.0438      0.089      0.492      0.623        -0.131     0.219
# Grayvalue213     0.3292      0.084      3.902      0.000         0.164     0.495
# Grayvalue214     0.1464      0.083      1.759      0.079        -0.017     0.310
# Grayvalue215    -0.0319      0.088     -0.362      0.717        -0.205     0.141
# Grayvalue216    -0.3194      0.086     -3.722      0.000        -0.488    -0.151
# Grayvalue217    -0.0351      0.081     -0.433      0.665        -0.194     0.124
# Grayvalue218     0.1698      0.086      1.983      0.047         0.002     0.338
# Grayvalue219    -0.1028      0.092     -1.114      0.265        -0.284     0.078
# Grayvalue220    -0.3128      0.103     -3.051      0.002        -0.514    -0.112
# Grayvalue221    -0.1304      0.124     -1.056      0.291        -0.373     0.112
# Grayvalue222    -0.3557      0.161     -2.213      0.027        -0.671    -0.041
# Grayvalue223    -0.1028      0.214     -0.480      0.631        -0.523     0.317
# Grayvalue224     0.0122      0.337      0.036      0.971        -0.649     0.673
# Grayvalue225    -0.0025      0.203     -0.012      0.990        -0.401     0.396
# Grayvalue226     0.1026      0.142      0.724      0.469        -0.175     0.380
# Grayvalue227     0.3406      0.109      3.128      0.002         0.127     0.554
# Grayvalue228    -0.0320      0.097     -0.330      0.741        -0.222     0.158
# Grayvalue229     0.1379      0.089      1.548      0.122        -0.037     0.313
# Grayvalue230    -0.1541      0.083     -1.849      0.065        -0.317     0.009
# Grayvalue231     0.0894      0.084      1.065      0.287        -0.075     0.254
# Grayvalue232     0.0233      0.086      0.271      0.787        -0.146     0.192
# Grayvalue233    -0.2219      0.085     -2.618      0.009        -0.388    -0.056
# Grayvalue234    -0.0138      0.090     -0.154      0.877        -0.190     0.162
# Grayvalue235    -0.1380      0.102     -1.354      0.176        -0.338     0.062
# Grayvalue236    -0.3320      0.120     -2.757      0.006        -0.568    -0.096
# Grayvalue237    -0.1128      0.157     -0.718      0.473        -0.421     0.195
# Grayvalue238    -0.0743      0.214     -0.347      0.728        -0.494     0.345
# Grayvalue239    -0.5116      0.266     -1.922      0.055        -1.033     0.010
# Grayvalue240    -0.3420      0.799     -0.428      0.669        -1.908     1.225
# Grayvalue241     0.2289      0.377      0.607      0.544        -0.510     0.968
# Grayvalue242     0.2172      0.258      0.843      0.399        -0.288     0.722
# Grayvalue243    -0.0113      0.177     -0.064      0.949        -0.358     0.335
# Grayvalue244     0.0634      0.137      0.462      0.644        -0.206     0.333
# Grayvalue245     0.2062      0.104      1.974      0.048         0.001     0.411
# Grayvalue246     0.3769      0.080      4.724      0.000         0.220     0.533
# Grayvalue247     0.0461      0.065      0.711      0.477        -0.081     0.173
# Grayvalue248    -0.3260      0.066     -4.949      0.000        -0.455    -0.197
# Grayvalue249    -0.0535      0.077     -0.697      0.486        -0.204     0.097
# Grayvalue250    -0.2557      0.104     -2.468      0.014        -0.459    -0.053
# Grayvalue251     0.4827      0.138      3.503      0.000         0.213     0.753
# Grayvalue252    -0.4358      0.171     -2.556      0.011        -0.770    -0.101
# Grayvalue253    -0.4769      0.223     -2.142      0.032        -0.913    -0.040
# Grayvalue254    -0.4391      0.293     -1.496      0.135        -1.014     0.136
# Grayvalue255    -0.2855      0.507     -0.563      0.574        -1.280     0.709
# ==============================================================================
# Omnibus:                       98.456   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.435
# Skew:                           0.243   Prob(JB):                     1.05e-24
# Kurtosis:                       3.358   Cond. No.                         562.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The flollowing result showed no much difference.

# %%
# prediction using the entire test set
pred_test = result_ols_intercept.predict(test_dat[['intercept']+colnames[1:]])
pred_test=np.round(pred_test)
pred_test[pred_test<0]=0
pred_test[pred_test>9]=9
print("Correct rate on test set:")
print(sum(pred_test==test_dat['Digit'])/num_test)
# prediction using the entire training set
pred_train = result_ols_intercept.predict(train_dat[['intercept']+colnames[1:]])
pred_train=np.round(pred_train)
pred_train[pred_train<0]=0
pred_train[pred_train>9]=9
print("Correct rate on entire train set:")
print(sum(pred_train==train_dat['Digit'])/num_train)
# prediction using the training set with the digit being 2
pred_train2 = result_ols_intercept.predict(train2_dat[['intercept']+colnames[1:]])
pred_train2=np.round(pred_train2)
pred_train2[pred_train2<0]=0
pred_train2[pred_train2>9]=9
print("Correct rate on training set with the digit being 2:")
print(sum(pred_train2==2)/num_train2)
# prediction using the training set with the digit being 3
pred_train3 = result_ols_intercept.predict(train3_dat[['intercept']+colnames[1:]])
pred_train3=np.round(pred_train2)
pred_train3[pred_train3<0]=0
pred_train3[pred_train3>9]=9
print("Correct rate on training set with the digit being 3:")
print(sum(pred_train3==3)/num_train3)
# Out:
# Correct rate on test set:
# 0.254608868959
# Correct rate on entire train set:
# 0.268824578247
# Correct rate on training set with the digit being 2:
# 0.236662106703
# Correct rate on training set with the digit being 3:
# 0.316109422492

# %% [markdown]
# Now let's implement $k$-nearest-neighbor by brute force. We use a max heap to store $k$ nodes nearest to the test point and update it iteratively with all the training points. The time complexity should be $O(MN)$, where $M$ is the size of the training set and $N$ is the test set. Another simple algorithm is k-d-tree, and cannot be used here. k-d-tree performs poorly and is almost the same as brute force as the dimmension here is 256, and $2^{256} >> 7000$.
#
# On my machine, one test will take about 7 seconds. Let's test for only 100 points and print the success rate.

# %%
from time import time
import heapq
gray_scale_col = colnames[1:]
def knn(k, p_test, training_set):
    def distance(p_test, p_train):
        return np.square(p_test[gray_scale_col].values-p_train[gray_scale_col].values).sum()
    minhp = [] # python only have min heap, use the negative of distance as priority value
    train_len = training_set.shape[0]
    if train_len <= k:
        pred = np.mean(training_set['Digit'])
    else:
        for i in range(k):
            heapq.heappush(minhp, (-distance(p_test, training_set.iloc[i]), i))
        for i in range(k, train_len):
            priority = -distance(p_test, training_set.iloc[i])
            if priority > minhp[0][0]:
                heapq.heapreplace(minhp, (priority, i))
        row_indices = [entry[1] for entry in minhp]
        pred = np.mean(training_set['Digit'][row_indices].values)
    pred=np.round(pred)
    if pred > 9:
        return 9
    elif pred <0:
        return 0
    else:
        return int(pred)
tic = time()
Ntests = 100
count = 0.0
for i in range(Ntests):
    pred = knn(15, test_dat.iloc[i], train_dat)
    if pred == int(test_dat['Digit'][i]):
        count+=1.0
print("Time cost in minutes:")
print((time()-tic)/60.0)
print("Success rate:")
print(count/Ntests)
# Out:
# Time cost in minutes:
# 12.342083319028218
# Success rate:
# 0.84

# %% [markdown]
# # Ex. 2.9
#
# This is a natrual result of least square estimator being Best Linear Unbiased Estimator (BLUE). Let's first try if we can explicitly calculate $\mathrm{E}[R_{tr}(\hat{\beta})]$ and $\mathrm{E}[R_{te}(\hat{\beta})]$ and compare their values. Finally we will prove the BLUE property of least square estimator and use it to derive the desired result.
#
# Let's use $\mathbf{X}$ to denote the $N\times p$ matrix with its $i$th row being $x_i$ in the training set and $\mathbf{y}$ being the $N\times 1$ vector with its $i$th element being $y_i$ in the training set. Let's denote the true value of $\beta$ as $\beta_{true}$, then the true model is as follows:
# $$\mathbf{y}=\mathbf{X}\beta_{\mbox{true}}+\mathbf{\varepsilon},$$
# where $\mathbf{\varepsilon}$ is the random error vector with zero mean and covariance of $\sigma^2\mathbf{I}$.
#
# The least square estimator of $\beta_{true}$ is:
# $$\hat{\beta}=(\mathbf{X}^{T}\mathbf{X})^{-1}\mathbf{X}^{T}\mathbf{y}.$$
#
# Next we can derive $\mathrm{E}[R_{tr}(\hat{\beta})]$:
# \begin{align*}
# \mathrm{E}[R_{tr}(\hat{\beta})] & =\mathrm{E}\left[\frac{1}{N}\sum_{i=1}^{N}(y_{i}-x_{i}^{T}\hat{\beta})\right]\\
#  & =\frac{1}{N}\mathrm{E}\left[\sum_{i=1}^{N}(y_{i}-x_{i}^{T}\hat{\beta})\right]\\
#  & =\frac{1}{N}\mathrm{E}\left[\left(\mathbf{X}\hat{\beta}-\mathbf{y}\right)^{T}\left(\mathbf{X}\hat{\beta}-\mathbf{y}\right)\right]\\
#  & =\frac{1}{N}\mathrm{E}\left[\left(\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\mathbf{X}^{T}\mathbf{\varepsilon}-\mathbf{\varepsilon}\right)^{T}\left(\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\mathbf{X}^{T}\mathbf{\varepsilon}-\mathbf{\varepsilon}\right)\right]\\
#  & =\frac{1}{N}\mathrm{E}\left[\mathbf{\varepsilon}^{T}\mathbf{\varepsilon}-\mathbf{\varepsilon}^{T}\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\mathbf{X}^{T}\mathbf{\varepsilon}\right]\\
#  & =\frac{1}{N}\mathrm{E}\left[\mathbf{\varepsilon}^{T}\mathbf{\varepsilon}\right]-\frac{1}{N}\mathrm{E}\left[\mathbf{\varepsilon}^{T}\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\mathbf{X}^{T}\mathbf{\varepsilon}\right]\\
#  & =\sigma^{2}-\frac{1}{N}\mathrm{E}\left[\mathbf{\varepsilon}^{T}\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\mathbf{X}^{T}\mathbf{\varepsilon}\right]\\
#  & =\sigma^{2}-\frac{1}{N}\mathrm{E}\left[\mathrm{Tr}\left(\left(\mathbf{X}^{T}\mathbf{\varepsilon}\mathbf{\varepsilon}^{T}\mathbf{X}\right)(\mathbf{X}^{T}\mathbf{X})^{-1}\right)\right]\\
#  & =\sigma^{2}-\frac{1}{N}\mathrm{E}\left[\mathrm{Tr}\left(\mathbf{X}^{T}\mathrm{E}\left[\mathbf{\varepsilon}\mathbf{\varepsilon}^{T}\right]\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\right)\right]\quad\mathbf{\varepsilon}\mbox{ being independent of }\mathbf{X}\\
#  & =\sigma^{2}-\frac{\sigma^{2}}{N}\mathrm{E}\left[\mathrm{Tr}\left(\mathbf{X}^{T}\cdot\mathbf{I}\cdot\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\right)\right]\\
#  & =\sigma^{2}-\frac{\sigma^{2}}{N}\mathrm{E}\left[\mathrm{Tr}\left(\mathbf{X}^{T}\mathbf{X}(\mathbf{X}^{T}\mathbf{X})^{-1}\right)\right]\\
#  & =\sigma^{2}-\frac{\sigma^{2}}{N}\mathrm{E}\left[\mathrm{Tr}(\mathbf{I})\right]\\
#  & =\sigma^{2}\left(1-\frac{p}{N}\right)
# \end{align*}
#
# For $\mathrm{E}[R_{te}(\hat{\beta})]$ we know that $\mathrm{E}[R_{te}(\hat{\beta})]=\mathrm{E}\left[\left(\tilde{y}_{1}-\tilde{x_{1}}\hat{\beta}\right)^{2}\right]$, due to the symmetry of each test point. Using the results in Ex. 2.5 (a), we know that:
# $$\mathrm{E}\left[\left(\tilde{y}_{1}-\tilde{x_{1}}\hat{\beta}\right)^{2}\right] =\sigma^{2}\left(1+\mathrm{E}\left[\tilde{x}_{1}^{T}\left(\mathbf{X}^{T}\mathbf{X}\right)^{-1}\tilde{x}_{1}\right]\right)
# $$
# When $N>p$ we know that the matrix $\mathbf{X}^{T}\mathbf{X}$ is almost surely positive definte. Then its inverse is also almost surely positive defnite, so $\tilde{x}_{1}^{T}\left(\mathbf{X}^{T}\mathbf{X}\right)^{-1}\tilde{x}_{1}$ is positive almost surely. In fact we know from Ex. 2.5 (b), that it will converge to $p/N$ as $N$ gets large. Therefore, we come to the following relation:
# \begin{align*}
# \mathrm{E}[R_{te}(\hat{\beta})] & =\sigma^{2}\left(1+\mathrm{E}\left[\tilde{x}_{1}^{T}\left(\mathbf{X}^{T}\mathbf{X}\right)^{-1}\tilde{x}_{1}\right]\right)\\
#  & >\sigma^{2}\\
#  & >\sigma^{2}\left(1-\frac{p}{N}\right)\\
#  & =\mathrm{E}[R_{tr}(\hat{\beta})]
# \end{align*}
# To complete the proof, let's quickly prove that the inverse of a postive definite matrix is also positive definite. Suppose matrix $A$ is positive definite so invertible, then $\forall x\ne0,\,\exists y\ne0,\,s.t.\,Ay=x \mbox{ and } x^{T}A^{-1}x=\left(y^{T}A^{T}\right)A^{-1}Ay=y^{T}A^{T}y=y^{T}Ay>0$.
